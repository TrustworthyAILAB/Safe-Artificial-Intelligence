# %% [markdown]
# # Python Basic

# %%
import pandas as pd

# %% [markdown]
# ## 1. Data Type

# %% [markdown]
# ### a. Int / Float

# %%
1 + 3
# Out:
# 4

# %%
17 / 4
# Out:
# 4.25

# %%
int(17 / 4), 17 // 4
# Out:
# (4, 4)

# %%
17 % 4
# Out:
# 1

# %%
import math
math.sqrt(9)
# Out:
# 3.0

# %%
e = math.e
math.log(e)
# Out:
# 1.0

# %%
math.pow(2, 2), 2**2
# Out:
# (4.0, 4)

# %%
type(math.pow(2, 2)), type(2**2)
# Out:
# (float, int)

# %%
2.13e2
# Out:
# 213.0

# %%
print("a = %0.5f, b = %5.0f" % (2018.0728, 2018.0728))
# Out:
# a = 2018.07280, b =  2018

# %% [markdown]
# ### b. Bool

# %%
a = True
b = False

# %%
# OR 연산
# Logical OR
a + b, bool(a + b)
# Out:
# (1, True)

# %%
# AND 연산
# Logical AND
a*b, bool(a*b)
# Out:
# (0, False)

# %%
a == False, b == False
# Out:
# (False, True)

# %%
type( 1 != 1 )
# Out:
# bool

# %% [markdown]
# ### c. String

# %%
a = "Hello?"
b = "World!"

# %%
type(a)
# Out:
# str

# %%
a[0]
# Out:
# 'H'

# %%
a[1:]
# Out:
# 'ello?'

# %%
a[-1]
# Out:
# '?'

# %%
a + b
# Out:
# 'Hello?World!'

# %%
a + " " + b
# Out:
# 'Hello? World!'

# %%
print("a = %s, b = %s" % (a, b))
# Out:
# a = Hello?, b = World!

# %% [markdown]
# ## 2. IF/WHILE/FOR

# %% [markdown]
# ### a. If

# %%
a = 2

# %%
if a == 1 :
    print("a is 1")
elif a==2 :
    print("a is 2")
else :
    print("a is not 1 or 2")
# Out:
# a is 2

# %% [markdown]
# ### b. While

# %%
while a < 5 : 
    a = a + 1
    print(a)
# Out:
# 3
# 4
# 5

# %%
b = 0 
while b < 10:
    b = b + 1
    if b % 2 != 0 :
        continue
    else :
        print(b)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# ### c. For

# %%
for i in range(0, 10) :
    print(" a > ", i, " : ", a > i )
# Out:
#  a >  0  :  True
#  a >  1  :  True
#  a >  2  :  True
#  a >  3  :  True
#  a >  4  :  True
#  a >  5  :  False
#  a >  6  :  False
#  a >  7  :  False
#  a >  8  :  False
#  a >  9  :  False

# %%
for i in range(0, 10, 2) :
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %% [markdown]
# ## 3. Collection

# %% [markdown]
# ### a. List

# %%
a = [1, 2, 3]
b = [4, 5, 6]

# %%
a + b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a[0], b[0]
# Out:
# (1, 4)

# %%
a.append(4)

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
del a[2:3]

# %%
a
# Out:
# [1, 2, 4]

# %%
a*2
# Out:
# [1, 2, 4, 1, 2, 4]

# %%
b.index(6)
# Out:
# 2

# %%
for i, n in enumerate(b) :
    print(i, "th : ", n)
# Out:
# 0 th :  4
# 1 th :  5
# 2 th :  6

# %% [markdown]
# ### b. Dictionary

# %%
a = {}

# %%
a['Greet'] = 'Hello'

# %%
a['Response'] = 'Hi'

# %%
a.keys()
# Out:
# dict_keys(['Greet', 'Response'])

# %%
a.values()
# Out:
# dict_values(['Hello', 'Hi'])

# %%
a['Greet']
# Out:
# 'Hello'

# %% [markdown]
# ## 4. Def/Exception/Class

# %% [markdown]
# ### a. Def

# %%
def add2(x) :
    return x + 2

# %%
add2(3)
# Out:
# 5

# %%
add2('HELLO')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 add2('HELLO')
#
# Cell In[47], line 2, in add2(x)
#       1 def add2(x) :
# ----> 2     return x + 2
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ### b. Exception

# %%
def add2(x) :
    try :
        return x + 2
    except TypeError as e :
        print("ERROR occured", e)

# %%
add2(3)
# Out:
# 5

# %%
add2('HELLO')
# Out:
# ERROR occured can only concatenate str (not "int") to str

# %% [markdown]
# ### c. Class

# %%
class A():
    def __init__(self):
        print("Initialization A")
        
    def info(self):
        print("Info of A")

# %%
a = A()
# Out:
# Initialization A

# %%
a.info()
# Out:
# Info of A

# %% [markdown]
# ## 5. Data Processing

# %% [markdown]
# ### a. TXT to String

# %%
f = open("./data/sample.txt", 'r')
while True:
    line = f.readline()
    if not line: break
    print(line)
    print("<Enter>")
f.close()
# Out:
# Natural Language Processing (NLP) is a technology that converts unstructured natural language spoken by humans into structured language data understandable by computers. This process enables computers to comprehend the intent of sentences and accurately grasp the speaker's intentions.
#
# <Enter>
#
#
# <Enter>
# In AI services, NLP plays a crucial role. It allows computers to parse natural language into morphemes, the smallest grammatical units, patterning linguistic structures to understand the overall meaning. NLP covers various tasks, including Part-of-Speech (POS) tagging, which resolves ambiguities within grammatical categories, stop-word removal, machine translation, and dialogue systems.
#
# <Enter>
#
#
# <Enter>
# Recently, deep learning-based NLP research has been growing. It has become possible to infer meaning from the entire context of sentences rather than just individual words. To apply deep learning, it's essential to obtain a corpus?linguistic data used for training.
#
# <Enter>
#
#
# <Enter>
# Speech recognition technology based on NLP is rapidly evolving due to advancements in network and computing technologies capable of storing large-scale voice data and processing it in real-time. The core of speech recognition technology is maintaining continuous dialogue with the interlocutor.
# <Enter>

# %%
f = open("./data/sample.txt", 'r')
lines = f.read()
print(lines)
f.close()
# Out:
# Natural Language Processing (NLP) is a technology that converts unstructured natural language spoken by humans into structured language data understandable by computers. This process enables computers to comprehend the intent of sentences and accurately grasp the speaker's intentions.
#
# In AI services, NLP plays a crucial role. It allows computers to parse natural language into morphemes, the smallest grammatical units, patterning linguistic structures to understand the overall meaning. NLP covers various tasks, including Part-of-Speech (POS) tagging, which resolves ambiguities within grammatical categories, stop-word removal, machine translation, and dialogue systems.
#
# Recently, deep learning-based NLP research has been growing. It has become possible to infer meaning from the entire context of sentences rather than just individual words. To apply deep learning, it's essential to obtain a corpus?linguistic data used for training.
#
# Speech recognition technology based on NLP is rapidly evolving due to advancements in network and computing technologies capable of storing large-scale voice data and processing it in real-time. The core of speech recognition technology is maintaining continuous dialogue with the interlocutor.

# %% [markdown]
# ### b. EXCEL to Dataframe

# %% [markdown]
# # Pandas는 Python 기반의 빠르고 유연한 오픈소스 데이터 분석/조작 라이브러리
# # Pandas is a fast, flexible open-source data analysis and manipulation tool in Python

# %%
import pandas as pd

# %%
xlsx = pd.read_excel('./data/sample.xlsx', sheet_name=0)

# %%
xlsx
# Out:
#              Name  Korean  Match
# 0     Kang Daniel       0     50
# 1     Kang Dongho       0     50
# 2       Kang Mina      70     85
# 3    Kwon Hyunbin      70     85
# 4      Kim Doyeon      40     70
# 5      Kim Samuel      90     95
# 6     Kim Sejeong      80     90
# 7       Kim Sohye      20     60
# 8     Kim Chungha      40     70
# 9     Noh Taehyun       0     50
# 10    Lai Kuanlin      70     85
# 11    Park Woojin      20     60
# 12    Park Jihoon      30     65
# 13   Bae Jinyoung      80     90
# 14   Ong Seongwoo      50     75
# 15   Yoo Yeonjung      40     70
# 16     Im Nayoung      50     75
# 17      Jeon Somi      10     55
# 18  Jung Chaeyeon      10     55
# 19  Zhou Jieqiong      50     75
# 20    Ju Haknyeon      50     75
# 21   Choi Yoojung      70     85
# 22   Takada Kenta      30     65
# 23    Ha Sungwoon      10     55

# %% [markdown]
# ### c. CSV to DataFrame

# %%
csv = pd.read_csv('./data/sample.csv', header=0, sep=',', encoding='euc-kr')

# %%
csv
# Out:
#              Name  Korean  Math
# 0     Kang Daniel      10    55
# 1     Kang Dongho      60    80
# 2       Kang Mina       0    50
# 3    Kwon Hyunbin      20    60
# 4      Kim Doyeon      60    80
# 5      Kim Samuel      30    65
# 6     Kim Sejeong      60    80
# 7       Kim Sohye      60    80
# 8     Kim Chungha      10    55
# 9     Noh Taehyun      40    70
# 10    Lai Kuanlin      70    85
# 11    Park Woojin      10    55
# 12    Park Jihoon      30    65
# 13   Bae Jinyoung       0    50
# 14   Ong Seongwoo      20    60
# 15   Yoo Yeonjung      60    80
# 16     Im Nayoung      90    95
# 17      Jeon Somi       0    50
# 18  Jung Chaeyeon       0    50
# 19  Zhou Jieqiong      90    95
# 20    Ju Haknyeon      10    55
# 21   Choi Yoojung      90    95
# 22   Takada Kenta      60    80
# 23    Ha Sungwoon      10    55

# %% [markdown]
# ### d. DataFrame to Numpy

# %% [markdown]
# # NumPy는 수치 연산, 선형대수, 난수 생성 등 과학계산 핵심 기능을 제공
# # NumPy provides core scientific-computing features like numeric ops, linear algebra, and random sampling

# %%
import numpy as np

# %%
data = xlsx.values

# %%
type(data)
# Out:
# numpy.ndarray

# %%
data
# Out:
# array([['Kang Daniel', 0, 50],
#        ['Kang Dongho', 0, 50],
#        ['Kang Mina', 70, 85],
#        ['Kwon Hyunbin', 70, 85],
#        ['Kim Doyeon', 40, 70],
#        ['Kim Samuel', 90, 95],
#        ['Kim Sejeong', 80, 90],
#        ['Kim Sohye', 20, 60],
#        ['Kim Chungha', 40, 70],
#        ['Noh Taehyun', 0, 50],
#        ['Lai Kuanlin', 70, 85],
#        ['Park Woojin', 20, 60],
#        ['Park Jihoon', 30, 65],
#        ['Bae Jinyoung', 80, 90],
#        ['Ong Seongwoo', 50, 75],
#        ['Yoo Yeonjung', 40, 70],
#        ['Im Nayoung', 50, 75],
#        ['Jeon Somi', 10, 55],
#        ['Jung Chaeyeon', 10, 55],
#        ['Zhou Jieqiong', 50, 75],
#        ['Ju Haknyeon', 50, 75],
#        ['Choi Yoojung', 70, 85],
#        ['Takada Kenta', 30, 65],
#        ['Ha Sungwoon', 10, 55]], dtype=object)

# %%
korean_score = data[:, 1]

# %%
print("Sum : ", np.sum(korean_score))
print("Mean : ", np.mean(korean_score))
print("Std : ", np.std(korean_score))
print("Max : ", np.max(korean_score))
# Out:
# Sum :  980
# Mean :  40.833333333333336
# Std :  27.525240941522906
# Max :  90
