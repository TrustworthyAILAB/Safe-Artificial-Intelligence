# %% [markdown]
# ## Jupyter Basic

# %% [markdown]
#     ### Click the title to rename the file
#     ### Press 'a' while selecting a cell to add a cell above
#     ### Press 'b' while selecting a cell to add a cell below
#     ### Press 'dd' while selecting a cell to delete it
#     ### Additionally, you can cut/copy/paste/move cells
#     ### Dragging is possible while holding Shift
#     ### Press 'M' while selecting a cell to convert it to Markdown
#     ### To revert to code, use the second list box from the right below the main widget
#     ### Press Ctrl + Enter to execute
#     ### Press Shift + Enter to execute and create a new line
#     ### Various other menu options are also available

# %% [markdown]
# ## Machine Learning Basic

# %% [markdown]
# Predict Math score with Korean score.

# %% [markdown]
# ### Raw Data

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('./data/sample.csv', header=0, sep=',', encoding='euc-kr')

# %%
data.head()
# Out:
#            Name  Korean  Math
# 0   Kang Daniel      10    55
# 1   Kang Dongho      60    80
# 2     Kang Mina       0    50
# 3  Kwon Hyunbin      20    60
# 4    Kim Doyeon      60    80

# %%
data = data[['Korean', 'Math']].values

# %%
data
# Out:
# array([[10, 55],
#        [60, 80],
#        [ 0, 50],
#        [20, 60],
#        [60, 80],
#        [30, 65],
#        [60, 80],
#        [60, 80],
#        [10, 55],
#        [40, 70],
#        [70, 85],
#        [10, 55],
#        [30, 65],
#        [ 0, 50],
#        [20, 60],
#        [60, 80],
#        [90, 95],
#        [ 0, 50],
#        [ 0, 50],
#        [90, 95],
#        [10, 55],
#        [90, 95],
#        [60, 80],
#        [10, 55]])

# %%
data.shape
# Out:
# (24, 2)

# %% [markdown]
# ### Split Data: Train data, Test Data

# %%
test_idxs = [5, 18, 22, 23]

# %%
train_idxs = [idx for idx in range(len(data)) if idx not in test_idxs]

# %%
train_data = data[train_idxs]

# %%
train_data
# Out:
# array([[10, 55],
#        [60, 80],
#        [ 0, 50],
#        [20, 60],
#        [60, 80],
#        [60, 80],
#        [60, 80],
#        [10, 55],
#        [40, 70],
#        [70, 85],
#        [10, 55],
#        [30, 65],
#        [ 0, 50],
#        [20, 60],
#        [60, 80],
#        [90, 95],
#        [ 0, 50],
#        [90, 95],
#        [10, 55],
#        [90, 95]])

# %%
test_data = data[test_idxs]

# %%
test_data
# Out:
# array([[30, 65],
#        [ 0, 50],
#        [60, 80],
#        [10, 55]])

# %% [markdown]
# ### Set Models

# %%
def f(w, x):
    return w*x

# %%
w = 1.5

# %% [markdown]
# ### Set Loss Function

# %%
def loss(pre, y):
    return ((pre-y)**2).mean()

# %% [markdown]
# ### Set Search Method

# %%
def search_method(loss, w):
    if loss > 100:
        w = w - 0.1
    else:
        w = w - 0.01
    return w

# %% [markdown]
# ### Split Data: Train data, Validation Data

# %%
train_len = 16
train_idxs = np.random.choice(len(train_data), train_len, replace=False)

# %%
train_idxs
# Out:
# array([ 0,  8, 14, 15,  5, 16,  3,  9, 10,  7,  2, 11, 18, 17,  4, 12])

# %%
train_data = train_data[train_idxs]

# %%
val_idxs = [idx for idx in range(len(train_data)) if idx not in train_idxs]

# %%
val_idxs
# Out:
# [1, 6, 13]

# %%
val_data = train_data[val_idxs]

# %% [markdown]
# ### Train and Validate

# %%
for i in range(5):
    x = train_data[:, 0]
    y = train_data[:, 1]
    
    pre = f(w, x)
    train_loss = loss(pre, y)
    
    x = val_data[:, 0]
    y = val_data[:, 1]
    pre = f(w, x)
    val_loss = loss(pre, y)
    
    print("--- Step %d ---"%(i+1))
    print("Current Model: \t %2.2f"%(w))
    print("Train Loss: \t %2.4f"%(train_loss))
    print("Val Loss: \t %2.4f"%(val_loss))
    
    w = search_method(train_loss, w)
# Out:
# --- Step 1 ---
# Current Model: 	 1.50
# Train Loss: 	 1200.0000
# Val Loss: 	 866.6667
# --- Step 2 ---
# Current Model: 	 1.40
# Train Loss: 	 1132.0000
# Val Loss: 	 727.0000
# --- Step 3 ---
# Current Model: 	 1.30
# Train Loss: 	 1108.0000
# Val Loss: 	 654.6667
# --- Step 4 ---
# Current Model: 	 1.20
# Train Loss: 	 1128.0000
# Val Loss: 	 649.6667
# --- Step 5 ---
# Current Model: 	 1.10
# Train Loss: 	 1192.0000
# Val Loss: 	 712.0000

# %% [markdown]
# ### Select Model

# %%
w_best = 1.60

# %% [markdown]
# ### Test Model

# %%
x = test_data[:, 0]
y = test_data[:, 1]
    
pre = f(w_best, x)

# %%
loss(pre, y)
# Out:
# np.float64(1141.5)

# %%
print("x", x)
print("y", y)
print("pre", pre)
# Out:
# x [30  0 60 10]
# y [65 50 80 55]
# pre [48.  0. 96. 16.]
